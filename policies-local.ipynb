# %%
# import numpy as np
import seaborn as sns
import pandas as pd
# import matplotlib.pyplot as plt

# %%
df= pd.read_csv("data/policies/eng-scot.csv", parse_dates=True, index_col='Date')

# %%
print(df)
# Out:
#             Unnamed: 0     CountryName CountryCode RegionName RegionCode  \
# Date
# 2020-01-01      113538  United Kingdom         GBR    England     UK_ENG
# 2020-01-02      113539  United Kingdom         GBR    England     UK_ENG
# 2020-01-03      113540  United Kingdom         GBR    England     UK_ENG
# 2020-01-04      113541  United Kingdom         GBR    England     UK_ENG
# 2020-01-05      113542  United Kingdom         GBR    England     UK_ENG
# ...                ...             ...         ...        ...        ...
# 2022-04-01      116011  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-02      116012  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-03      116013  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-04      116014  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-05      116015  United Kingdom         GBR   Scotland     UK_SCO
#
#            Jurisdiction  C1_School closing  C1_Flag  C2_Workplace closing  \
# Date
# ...

# %%
#df = df[(df.RegionName == "England") | (df.RegionName == "Scotland")]

# %%
print(df)
# Out:
#             Unnamed: 0     CountryName CountryCode RegionName RegionCode  \
# Date
# 2020-01-01      113538  United Kingdom         GBR    England     UK_ENG
# 2020-01-02      113539  United Kingdom         GBR    England     UK_ENG
# 2020-01-03      113540  United Kingdom         GBR    England     UK_ENG
# 2020-01-04      113541  United Kingdom         GBR    England     UK_ENG
# 2020-01-05      113542  United Kingdom         GBR    England     UK_ENG
# ...                ...             ...         ...        ...        ...
# 2022-04-01      116011  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-02      116012  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-03      116013  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-04      116014  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-05      116015  United Kingdom         GBR   Scotland     UK_SCO
#
#            Jurisdiction  C1_School closing  C1_Flag  C2_Workplace closing  \
# Date
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Unnamed: 0     CountryName CountryCode RegionName RegionCode  \
# Date
# 2020-01-01      113538  United Kingdom         GBR    England     UK_ENG
# 2020-01-02      113539  United Kingdom         GBR    England     UK_ENG
# 2020-01-03      113540  United Kingdom         GBR    England     UK_ENG
# 2020-01-04      113541  United Kingdom         GBR    England     UK_ENG
# 2020-01-05      113542  United Kingdom         GBR    England     UK_ENG
# ...                ...             ...         ...        ...        ...
# 2022-04-01      116011  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-02      116012  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-03      116013  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-04      116014  United Kingdom         GBR   Scotland     UK_SCO
# 2022-04-05      116015  United Kingdom         GBR   Scotland     UK_SCO
#
# ...

# %%
df.sample(10, random_state=19)
# Out:
#             Unnamed: 0     CountryName CountryCode RegionName RegionCode  \
# Date
# 2020-11-21      115515  United Kingdom         GBR   Scotland     UK_SCO
# 2020-03-06      115255  United Kingdom         GBR   Scotland     UK_SCO
# 2021-11-27      114234  United Kingdom         GBR    England     UK_ENG
# 2020-11-19      113861  United Kingdom         GBR    England     UK_ENG
# 2021-07-11      115747  United Kingdom         GBR   Scotland     UK_SCO
# 2021-07-08      114092  United Kingdom         GBR    England     UK_ENG
# 2020-12-23      115547  United Kingdom         GBR   Scotland     UK_SCO
# 2021-01-06      115561  United Kingdom         GBR   Scotland     UK_SCO
# 2020-08-30      115432  United Kingdom         GBR   Scotland     UK_SCO
# 2021-10-26      115854  United Kingdom         GBR   Scotland     UK_SCO
#
#            Jurisdiction  C1_School closing  C1_Flag  C2_Workplace closing  \
# Date
# 2020-11-21  STATE_TOTAL                1.0      1.0                   2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1652 entries, 2020-01-01 to 2022-04-05
# Data columns (total 61 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Unnamed: 0                                                                       1652 non-null   int64
#  1   CountryName                                                                      1652 non-null   object
#  2   CountryCode                                                                      1652 non-null   object
#  3   RegionName                                                                       1652 non-null   object
#  4   RegionCode                                                                       1652 non-null   object
# ...

# %%
df = df.fillna(0)

# %%
#df.plot.line(x='Date', y=['C1_School closing','C2_Workplace closing','C3_Cancel public events','C4_Restrictions on gatherings','C5_Close public transport','C6_Stay at home requirements','C7_Restrictions on internal movement','C8_International travel controls','E1_Income support','H1_Public information campaigns','H2_Testing policy','H3_Contact tracing','H6_Facial Coverings','H7_Vaccination policy','H8_Protection of elderly people', 'M1_Wildcard'],figsize=(50, 30))
df[(df.index > pd.to_datetime('2021-11-01')) & (df['RegionName'] == 'England')].plot.line(y=[
    'C1_School closing',
    'C2_Workplace closing',
    'C3_Cancel public events',
    'C4_Restrictions on gatherings',
    'C5_Close public transport',
    'C6_Stay at home requirements',
    'C7_Restrictions on internal movement',
    'C8_International travel controls',
    'H3_Contact tracing',
    'H6_Facial Coverings',
    'H8_Protection of elderly people',
    'M1_Wildcard',
    'H7_Vaccination policy'
],figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# * No change in vaccination policy, testing policy, public information campaign
# * Changing policies:
#     * Masks + cancellation of public events + workplace closing
#     * Schools
#     * International Travel
# * \+ vaccination

# %%
df.plot.line(x='Date', y=['E3_Fiscal measures'],figsize=(50, 30))

# %%
print(df.E3_Fiscal measures)
